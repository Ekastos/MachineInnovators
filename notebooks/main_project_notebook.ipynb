# %% [markdown]
# # Progetto Finale MLOps: Monitoraggio della Reputazione Online

# %% [markdown]
# ## Consegna del Progetto
#
# Come da richiesta, il codice sorgente completo, inclusa la pipeline CI/CD, l'implementazione del modello e gli script di automazione, è ospitato sulla seguente repository pubblica GitHub:
#
# **Link progetto github:**  *https://github.com/Ekastos/MachineInnovators.git*

# %% [markdown]
# ### Risorse Aggiuntive
#
# **Live Demo (Hugging Face Spaces):** https://huggingface.co/spaces/LorenzoIVF/Sentiment-Analyzer-MachineInnovators
